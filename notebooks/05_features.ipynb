# %% [markdown]
# # Stage 7: Feature Engineering Notebook
# Extracts name, address, country, and cross-field similarity features for candidate pairs.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path("..").resolve()))

from src.utils.stage_runner import StageController
controller = StageController("../configs/config.yaml")
controller.run_stage("features")
