# %% [markdown]
# # Stage 10: Evaluation & Threshold Optimization Notebook
# Optimizes entity-level decision thresholds for macro F0.5 and singletons.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path("..").resolve()))

from src.utils.stage_runner import StageController
controller = StageController("../configs/config.yaml")
controller.run_stage("threshold_optimization")
