# %% [markdown]
# # Stage 5 & 6: Candidate Generation & Blocking Evaluation Notebook
# Generates multi-rule candidate pairs and evaluates candidate recall against ground truth.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path("..").resolve()))

from src.utils.stage_runner import StageController
controller = StageController("../configs/config.yaml")
controller.run_stage("blocking")
controller.run_stage("candidate_recall")
