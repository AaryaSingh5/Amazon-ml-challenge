# %% [markdown]
# # Stage 8: Rule-Based Similarity Baseline Notebook
# Evaluates baseline similarity heuristics and sets the initial F0.5 performance benchmark.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path("..").resolve()))

from src.utils.stage_runner import StageController
controller = StageController("../configs/config.yaml")
controller.run_stage("baseline")
