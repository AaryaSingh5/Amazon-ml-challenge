# %% [markdown]
# # Stage 9: First Machine Learning Matching Model Notebook
# Trains pairwise binary classifiers (LightGBM/XGBoost) to predict match probabilities on candidate pairs.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path("..").resolve()))

from src.utils.stage_runner import StageController
controller = StageController("../configs/config.yaml")
controller.run_stage("training")
